# %% [markdown]
#                      **PROJECT 1**
#
#                 BREST_CANCER_PREDICTION

# %%
#project1
#breast cancer
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
import pandas as pd
mydf=pd.read_csv("/content/Coimbra_breast_cancer_dataset.csv")
mydf
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# 2     9.27715  554.697               1
# 3    12.76600  928.220               1
# 4    10.57635  773.920               1
# ..        ...      ...             ...
# 111  10.96000  268.230               2
# 112   7.32000  330.160               2
# 113  10.33000  314.050               2
# 114   3.27000  392.460               2
# 115   4.35000   90.090               2
#
# [116 rows x 10 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
#linear regression
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
bmi=np.array(mydf['BMI']).reshape(-1,1)
insulin=np.array(mydf['Insulin'])
LR.fit(bmi,insulin)
LR.predict([[5.6]])
# Out:
# array([3.6067997])

# %%
#DECISION TREE
BMI=float(input("enter bmi"))
Glucose=int(input("enter glucose"))
Insulin=float(input("enter insulin"))
HOMA=float(input("enter homa"))
Leptin=float(input("enter leptin"))
Adiponectin=float(input("enter adiponectin"))
Resistin=float(input("enter resistin"))
MCP1=float(input("enter mcp"))
features_cols=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1']
features=mydf[features_cols]
target=mydf.Classification
DT1=DecisionTreeClassifier()
model=DT1.fit(features,target)
a=model.predict([[BMI,Glucose,Insulin,HOMA,Leptin,Adiponectin,Resistin,MCP1]])
if a==1:
  print("have cancer")
else:
  print("not having  cancer")
# Out:
# enter bmi67
# enter glucose91
# enter insulin58
# enter homa55
# enter leptin58.5
# enter adiponectin85
# enter resistin85
# enter mcp96
# not having  cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree

# %%
plot_tree(DT1)
# Out:
# [Text(0.4659090909090909, 0.9545454545454546, 'x[1] <= 91.5\ngini = 0.495\nsamples = 116\nvalue = [52, 64]'),
#  Text(0.22727272727272727, 0.8636363636363636, 'x[6] <= 13.248\ngini = 0.42\nsamples = 50\nvalue = [35, 15]'),
#  Text(0.13636363636363635, 0.7727272727272727, 'x[2] <= 30.067\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.09090909090909091, 0.6818181818181818, 'x[6] <= 3.281\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.045454545454545456, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13636363636363635, 0.5909090909090909, 'x[4] <= 8.747\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.09090909090909091, 0.5, 'x[1] <= 81.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.045454545454545456, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13636363636363635, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18181818181818182, 0.5, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.18181818181818182, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3181818181818182, 0.7727272727272727, 'x[0] <= 30.027\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.2727272727272727, 0.6818181818181818, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.36363636363636365, 0.6818181818181818, 'x[3] <= 5.137\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.3181818181818182, 0.5909090909090909, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4090909090909091, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7045454545454546, 0.8636363636363636, 'x[4] <= 7.24\ngini = 0.382\nsamples = 66\nvalue = [17, 49]'),
#  Text(0.6590909090909091, 0.7727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.75, 0.7727272727272727, 'x[0] <= 32.481\ngini = 0.331\nsamples = 62\nvalue = [13, 49]'),
#  Text(0.5909090909090909, 0.6818181818181818, 'x[6] <= 4.558\ngini = 0.237\nsamples = 51\nvalue = [7, 44]'),
#  Text(0.5, 0.5909090909090909, 'x[5] <= 10.445\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.45454545454545453, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5454545454545454, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6818181818181818, 0.5909090909090909, 'x[7] <= 68.221\ngini = 0.159\nsamples = 46\nvalue = [4, 42]'),
#  Text(0.6363636363636364, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7272727272727273, 0.5, 'x[5] <= 2.952\ngini = 0.124\nsamples = 45\nvalue = [3, 42]'),
#  Text(0.6363636363636364, 0.4090909090909091, 'x[1] <= 103.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5909090909090909, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6818181818181818, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8181818181818182, 0.4090909090909091, 'x[1] <= 96.5\ngini = 0.089\nsamples = 43\nvalue = [2, 41]'),
#  Text(0.7727272727272727, 0.3181818181818182, 'x[1] <= 95.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.7272727272727273, 0.22727272727272727, 'x[0] <= 27.025\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.6818181818181818, 0.13636363636363635, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7727272727272727, 0.13636363636363635, 'x[1] <= 93.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7272727272727273, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8181818181818182, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8181818181818182, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8636363636363636, 0.3181818181818182, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.9090909090909091, 0.6818181818181818, 'x[6] <= 10.109\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.8636363636363636, 0.5909090909090909, 'x[3] <= 1.171\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8181818181818182, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9090909090909091, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9545454545454546, 0.5909090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]')]

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
BMI=float(input("enter bmi"))
Glucose=int(input("enter glucose"))
Insulin=float(input("enter insulin"))
HOMA=float(input("enter homa i.e.used to quantify insulin resistance and beta-cell function"))
Leptin=float(input("enter leptin"))
Adiponectin=float(input("enter adiponectin"))
Resistin=float(input("enter resistin"))
MCP1=float(input("enter mcp"))
features_cols=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1']
features=mydf[features_cols]
target=mydf.Classification
RF1=RandomForestClassifier()
model=RF1.fit(features,target)
n_estimators=10
a=model.predict([[BMI,Glucose,Insulin,HOMA,Leptin,Adiponectin,Resistin,MCP1]])
if a==1:
  print("have cancer")
else:
  print("not having  cancer")
# Out:
# enter bmi85
# enter glucose89
# enter insulin56
# enter homa i.e.used to quantify insulin resistance and beta-cell function85
# enter leptin78
# enter adiponectin96
# enter resistin89
# enter mcp56
# have cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir ="tree_visualizations_on_breast_cancer"
os.makedirs(output_dir,exist_ok=True)

# %%
for i, tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['BMI','Glucose','Insulin','HOMA','Leptin','Adiponectin','Resistin','MCP.1'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to tree_visualizations_on_breast_cancer/tree_99.png

# %% [markdown]
# **PROJECT 2**
#
# PREDICTING WHETHER THE STUDENT WILL GET PLQACED OR NOT

# %%
#project 2
# placed or not placed
import pandas as pd
df=pd.read_csv("/content/employement.csv")
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  Unnamed: 14  \
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed          NaN
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed          NaN
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed          NaN
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed          NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed          NaN
# ..         ...    ...      ...            ...    ...         ...          ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed          NaN
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed          NaN
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed          NaN
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed          NaN
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed          NaN
#
#      Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18
# 0            NaN          NaN          NaN         NaN
# 1            NaN          NaN          NaN         NaN
# 2            NaN          NaN          NaN         NaN
# 3            NaN          NaN          NaN         NaN
# 4            NaN          NaN          NaN         NaN
# ..           ...          ...          ...         ...
# 210          NaN          NaN          NaN         NaN
# 211          NaN          NaN          NaN         NaN
# 212          NaN          NaN          NaN         NaN
# 213          NaN          NaN          NaN         NaN
# 214          NaN          NaN          NaN         NaN
#
# [215 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
dfn = df['status']

# %%
dfn
# Out:
# 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
#Decision tree algorithm
ssc_p=float(input("Enter SSC percentage:"))
hsc_p=float(input("Enter HSC percentage:"))
degree_p=float(input("Enter degree percentage:"))
etest_p	=float(input("Enter entrance percentage:"))
mba_p=float(input("Enter MBA percentage:"))
feature_col=['ssc_p','hsc_p','degree_p','etest_p','mba_p']
feature=df[feature_col]#features
Target=df.status #Target variable
DT=DecisionTreeClassifier()#creating the model
model=DT.fit(feature,Target)#fitting the model
print(model)
a=model.predict([[ssc_p,hsc_p,degree_p,etest_p,mba_p]])
if a == "Placed":
  print("Yay! you are PLACED..")
else:
  print("Sorry you are NOT PLACED Better luck next time!")
# Out:
# Enter SSC percentage:67
# Enter HSC percentage:91
# Enter degree percentage:58
# Enter entrance percentage:55
# Enter MBA percentage:58.5
# DecisionTreeClassifier()
# Yay! you are PLACED..
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree
from sklearn.ensemble import RandomForestClassifier

# %%
ssc_p=float(input("Enter SSC percentage:"))
hsc_p=float(input("Enter HSC percentage:"))
degree_p=float(input("Enter degree percentage:"))
etest_p	=float(input("Enter entrance percentage:"))
mba_p=float(input("Enter MBA percentage:"))
feature_col=['ssc_p','hsc_p','degree_p','etest_p','mba_p']
feature=df[feature_col]#features
Target=df.status #Target variable
RF=RandomForestClassifier()#creating the model
model=RF.fit(feature,Target)#fitting the model
n_estimators=10
print(model)
res=model.predict([[ssc_p,hsc_p,degree_p,etest_p,mba_p]])
if res=="Placed":
  print("you are placed")
else:
  print("you are not placed")
# Out:
# Enter SSC percentage:67
# Enter HSC percentage:91
# Enter degree percentage:58
# Enter entrance percentage:55
# Enter MBA percentage:58.80
# RandomForestClassifier()
# you are placed
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#creating a folder
#saving all decisions
import os
output_dir=" Placements Tree Visualization"
os.makedirs(output_dir,exist_ok=True)

# %%
#writing path
for i,tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['ssc_p','hsc_p','degree_p','etest_p','mba_p'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to  Placements Tree Visualization/tree_99.png

# %% [markdown]
# **PROJECT3**
#
# EMPOLOYEE ATTRITION

# %%
#project-3
import pandas as pd
mydf3=pd.read_csv("/content/WA_Fn-UseC_-HR-Employee-Attrition.csv")
mydf3
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
#trees
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
DistanceFromHome=int(input("enter DistanceFromHome"))
DailyRate=int(input("enter DailyRate"))
WorkLifeBalance=int(input("enter WorkLifeBalance"))
JobSatisfaction=int(input("enter JobSatisfaction	"))
features_col=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction']
features=mydf3[features_col]
target=mydf3.Attrition
DT2=DecisionTreeClassifier()
model=DT2.fit(features,target)
a=model.predict([[DistanceFromHome,DailyRate,WorkLifeBalance,JobSatisfaction]])
if a=="Yes":
  print("leave the company")
else:
  print("not leave the company")
# Out:
# enter DistanceFromHome6
# enter DailyRate613
# enter WorkLifeBalance3
# enter JobSatisfaction	1
# not leave the company
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import export_graphviz,plot_tree
plot_tree(DT2)
# Out:
# [Text(0.30078301212118136, 0.9875, 'x[2] <= 1.5\ngini = 0.27\nsamples = 1470\nvalue = [1233, 237]'),
#  Text(0.06895789590009946, 0.9625, 'x[1] <= 1146.0\ngini = 0.43\nsamples = 80\nvalue = [55, 25]'),
#  Text(0.056580837661620066, 0.9375, 'x[1] <= 1091.0\ngini = 0.479\nsamples = 58\nvalue = [35, 23]'),
#  Text(0.04950823295391756, 0.9125, 'x[0] <= 25.5\ngini = 0.46\nsamples = 53\nvalue = [34, 19]'),
#  Text(0.0459719306000663, 0.8875, 'x[0] <= 22.0\ngini = 0.475\nsamples = 49\nvalue = [30, 19]'),
#  Text(0.0388993258923638, 0.8625, 'x[0] <= 17.5\ngini = 0.449\nsamples = 44\nvalue = [29, 15]'),
#  Text(0.03536302353851254, 0.8375, 'x[0] <= 9.5\ngini = 0.469\nsamples = 40\nvalue = [25, 15]'),
#  Text(0.021217814123107526, 0.8125, 'x[1] <= 918.0\ngini = 0.412\nsamples = 31\nvalue = [22, 9]'),
#  Text(0.01768151176925627, 0.7875, 'x[1] <= 497.5\ngini = 0.453\nsamples = 26\nvalue = [17, 9]'),
#  Text(0.007072604707702508, 0.7625, 'x[0] <= 1.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.003536302353851254, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.010608907061553763, 0.7375, 'x[1] <= 299.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.007072604707702508, 0.7125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.014145209415405017, 0.7125, 'x[1] <= 366.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.010608907061553763, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01768151176925627, 0.6875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.028290418830810033, 0.7625, 'x[1] <= 525.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.02475411647695878, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03182672118466129, 0.7375, 'x[1] <= 867.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.028290418830810033, 0.7125, 'x[1] <= 683.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.02475411647695878, 0.6875, 'x[1] <= 594.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.021217814123107526, 0.6625, 'x[3] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.01768151176925627, 0.6375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02475411647695878, 0.6375, 'x[1] <= 528.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.021217814123107526, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.028290418830810033, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.028290418830810033, 0.6625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03182672118466129, 0.6875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03536302353851254, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02475411647695878, 0.7875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.04950823295391756, 0.8125, 'x[1] <= 1006.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.0459719306000663, 0.7875, 'x[1] <= 619.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.04243562824621505, 0.7625, 'x[1] <= 293.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.0388993258923638, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0459719306000663, 0.7375, 'x[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04243562824621505, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04950823295391756, 0.7125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04950823295391756, 0.7625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.053044535307768814, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04243562824621505, 0.8375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.053044535307768814, 0.8625, 'x[1] <= 354.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.04950823295391756, 0.8375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.056580837661620066, 0.8375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.053044535307768814, 0.8875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.06365344236932258, 0.9125, 'x[0] <= 16.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.060117140015471325, 0.8875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06718974472317384, 0.8875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08133495413857884, 0.9375, 'x[3] <= 1.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.0777986517847276, 0.9125, 'x[1] <= 1285.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07426234943087634, 0.8875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08133495413857884, 0.8875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0848712564924301, 0.9125, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.5326081283422633, 0.9625, 'x[0] <= 11.5\ngini = 0.259\nsamples = 1390\nvalue = [1178, 212]'),
#  Text(0.23918920949699207, 0.9375, 'x[3] <= 1.5\ngini = 0.229\nsamples = 999\nvalue = [867, 132]'),
#  Text(0.15830478505912254, 0.9125, 'x[0] <= 8.5\ngini = 0.311\nsamples = 192\nvalue = [155, 37]'),
#  Text(0.08840755884628136, 0.8875, 'x[1] <= 105.0\ngini = 0.271\nsamples = 155\nvalue = [130, 25]'),
#  Text(0.0848712564924301, 0.8625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0919438612001326, 0.8625, 'x[1] <= 280.0\ngini = 0.263\nsamples = 154\nvalue = [130, 24]'),
#  Text(0.06818432976019449, 0.8375, 'x[1] <= 130.0\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.06464802740634325, 0.8125, 'x[0] <= 3.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.06111172505249199, 0.7875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06818432976019449, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07172063211404575, 0.8125, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.11570339264007072, 0.8375, 'x[1] <= 320.0\ngini = 0.289\nsamples = 131\nvalue = [108, 23]'),
#  Text(0.11216709028621948, 0.8125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11923969499392198, 0.8125, 'x[0] <= 1.5\ngini = 0.273\nsamples = 129\nvalue = [108, 21]'),
#  Text(0.07525693446789701, 0.7875, 'x[2] <= 3.5\ngini = 0.18\nsamples = 40\nvalue = [36, 4]'),
#  Text(0.06818432976019449, 0.7625, 'x[1] <= 704.5\ngini = 0.149\nsamples = 37\nvalue = [34, 3]'),
#  Text(0.06464802740634325, 0.7375, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.07172063211404575, 0.7375, 'x[1] <= 816.0\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.06464802740634325, 0.7125, 'x[1] <= 758.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06111172505249199, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06818432976019449, 0.6875, 'x[1] <= 790.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06464802740634325, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07172063211404575, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07879323682174826, 0.7125, 'x[1] <= 1354.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.07525693446789701, 0.6875, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.08232953917559951, 0.6875, 'x[1] <= 1390.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.07879323682174826, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08586584152945077, 0.6625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08232953917559951, 0.7625, 'x[1] <= 796.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07879323682174826, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08586584152945077, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16322245551994696, 0.7875, 'x[0] <= 3.5\ngini = 0.309\nsamples = 89\nvalue = [72, 17]'),
#  Text(0.13802630124875676, 0.7625, 'x[1] <= 1111.5\ngini = 0.394\nsamples = 37\nvalue = [27, 10]'),
#  Text(0.12299701624488894, 0.7375, 'x[0] <= 2.5\ngini = 0.461\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.1070836556525583, 0.7125, 'x[1] <= 467.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.09647474859100454, 0.6875, 'x[2] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09293844623715328, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10001105094485578, 0.6625, 'x[1] <= 454.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09647474859100454, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10354735329870704, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11769256271411206, 0.6875, 'x[2] <= 3.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.1141562603602608, 0.6625, 'x[1] <= 720.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.11061995800640954, 0.6375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.
5\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.270527130069621, 0.8375, 'x[1] <= 143.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.2669908277157697, 0.8125, 'x[1] <= 142.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.26345452536191843, 0.7875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.270527130069621, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2740634324234722, 0.8125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.27759973477732347, 0.8375, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.3731564401539535, 0.8875, 'x[1] <= 204.0\ngini = 0.216\nsamples = 756\nvalue = [663, 93]'),
#  Text(0.28820864183887723, 0.8625, 'x[1] <= 202.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.28467233948502596, 0.8375, 'x[0] <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.28113603713117474, 0.8125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.28820864183887723, 0.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2917449441927285, 0.8375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4581042384690297, 0.8625, 'x[1] <= 504.5\ngini = 0.213\nsamples = 752\nvalue = [661, 91]'),
#  Text(0.298817548900431, 0.8375, 'x[1] <= 499.5\ngini = 0.275\nsamples = 158\nvalue = [132, 26]'),
#  Text(0.2952812465465797, 0.8125, 'x[0] <= 9.5\ngini = 0.253\nsamples = 155\nvalue = [132, 23]'),
#  Text(0.2917449441927285, 0.7875, 'x[0] <= 1.5\ngini = 0.275\nsamples = 140\nvalue = [117, 23]'),
#  Text(0.269753563929716, 0.7625, 'x[1] <= 335.5\ngini = 0.124\nsamples = 30\nvalue = [28, 2]'),
#  Text(0.2662172615758647, 0.7375, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.2732898662835672, 0.7375, 'x[1] <= 355.5\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.269753563929716, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2768261686374185, 0.7125, 'x[3] <= 2.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.2732898662835672, 0.6875, 'x[1] <= 415.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.269753563929716, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2768261686374185, 0.6625, 'x[1] <= 437.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2732898662835672, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.28036247099126976, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.28036247099126976, 0.6875, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.31373632445574096, 0.7625, 'x[1] <= 229.0\ngini = 0.309\nsamples = 110\nvalue = [89, 21]'),
#  Text(0.31020002210188974, 0.7375, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.31727262680959223, 0.7375, 'x[1] <= 240.5\ngini = 0.332\nsamples = 100\nvalue = [79, 21]'),
#  Text(0.29450768040667474, 0.7125, 'x[0] <= 6.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2909713780528235, 0.6875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.298043982760526, 0.6875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34003757321250966, 0.7125, 'x[1] <= 303.5\ngini = 0.307\nsamples = 95\nvalue = [77, 18]'),
#  Text(0.3051165874682285, 0.6875, 'x[2] <= 2.5\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.2909713780528235, 0.6625, 'x[3] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.28743507569897225, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29450768040667474, 0.6375, 'x[1] <= 298.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2909713780528235, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.298043982760526, 0.6125, 'x[1] <= 301.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.29450768040667474, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3015802851143773, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31926179688363354, 0.6625, 'x[0] <= 3.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.3086528898220798, 0.6375, 'x[1] <= 259.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.3051165874682285, 0.6125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.31218919217593105, 0.6125, 'x[1] <= 274.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3086528898220798, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31572549452978227, 0.5875, 'x[3] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.31218919217593105, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31926179688363354, 0.5625, 'x[1] <= 288.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.31572549452978227, 0.5375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3227980992374848, 0.5375, 'x[1] <= 296.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.31926179688363354, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32633440159133603, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3298707039451873, 0.6375, 'x[1] <= 255.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.32633440159133603, 0.6125, 'x[0] <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3227980992374848, 0.5875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3298707039451873, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3334070062990386, 0.6125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3749585589567908, 0.6875, 'x[0] <= 8.5\ngini = 0.262\nsamples = 71\nvalue = [60, 11]'),
#  Text(0.35285666924522047, 0.6625, 'x[1] <= 335.5\ngini = 0.225\nsamples = 62\nvalue = [54, 8]'),
#  Text(0.3493203668913692, 0.6375, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.35639297159907174, 0.6375, 'x[1] <= 351.0\ngini = 0.273\nsamples = 49\nvalue = [41, 8]'),
#  Text(0.34755221571444356, 0.6125, 'x[3] <= 3.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.34401591336059234, 0.5875, 'x[3] <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.34047961100674107, 0.5625, 'x[1] <= 343.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3369433086528898, 0.5375, 'x[0] <= 7.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3334070062990386, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34047961100674107, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34401591336059234, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34755221571444356, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35108851806829483, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36523372748369987, 0.6125, 'x[3] <= 3.5\ngini = 0.236\nsamples = 44\nvalue = [38, 6]'),
#  Text(0.3581611227759973, 0.5875, 'x[1] <= 416.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.3546248204221461, 0.5625, 'x[2] <= 2.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.35108851806829483, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3581611227759973, 0.5375, 'x[0] <= 6.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.3546248204221461, 0.5125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.3616974251298486, 0.5125, 'x[1] <= 394.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3581611227759973, 0.4875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36523372748369987, 0.4875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3616974251298486, 0.5625, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.37230633219140236, 0.5875, 'x[1] <= 483.0\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.3687700298375511, 0.5625, 'x[1] <= 415.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.36523372748369987, 0.5375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.37230633219140236, 0.5375, 'x[1] <= 429.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.3687700298375511, 0.5125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37584263454525363, 0.5125, 'x[1] <= 469.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.37230633219140236, 0.4875, 'x[0] <= 5.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.3687700298375511, 0.4625, 'x[1] <= 439.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.36523372748369987, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37230633219140236, 0.4375, 'x[2] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3687700298375511, 0.4125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37584263454525363, 0.4125, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.37584263454525363, 0.4625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37937893689910485, 0.4875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37584263454525363, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39706044866836115, 0.6625, 'x[2] <= 3.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.3935241463145099, 0.6375, 'x[1] <= 430.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.3899878439606586, 0.6125, 'x[1] <= 418.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.3864515416068074, 0.5875, 'x[2] <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3829152392529561, 0.5625, 'x[1] <= 330.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.37937893689910485, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3864515416068074, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3899878439606586, 0.5625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3935241463145099, 0.5875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39706044866836115, 0.6125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.40059675102221237, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.298817548900431, 0.7875, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.30235385125428227, 0.8125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6173909280376285, 0.8375, 'x[1] <= 1495.5\ngini = 0.195\nsamples = 594\nvalue = [529, 65]'),
#  Text(0.610318323329926, 0.8125, 'x[1] <= 526.0\ngini = 0.193\nsamples = 592\nvalue = [528, 64]'),
#  Text(0.6067820209760747, 0.7875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.6138546256837772, 0.7875, 'x[1] <= 527.5\ngini = 0.196\nsamples = 580\nvalue = [516, 64]'),
#  Text(0.6044897053541828, 0.7625, 'x[3] <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6009534030003315, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.608026007708034, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6232195460133716, 0.7625, 'x[1] <= 1449.5\ngini = 0.194\nsamples = 578\nvalue = [515, 63]'),
#  Text(0.6150986124157366, 0.7375, 'x[1] <= 1444.5\ngini = 0.199\nsamples = 552\nvalue = [490, 62]'),
#  Text(0.6115623100618853, 0.7125, 'x[1] <= 1374.0\ngini = 0.192\nsamples = 549\nvalue = [490, 59]'),
#  Text(0.5988567452204664, 0.6875, 'x[1] <= 1359.0\ngini = 0.2\nsamples = 514\nvalue = [456, 58]'),
#  Text(0.5840545225991822, 0.6625, 'x[1] <= 1324.0\ngini = 0.19\nsamples = 507\nvalue = [453, 54]'),
#  Text(0.580518220245331, 0.6375, 'x[1] <= 1319.0\ngini = 0.197\nsamples = 487\nvalue = [433, 54]'),
#  Text(0.5615226820643165, 0.6125, 'x[1] <= 1109.0\ngini = 0.192\nsamples = 482\nvalue = [430, 52]'),
#  Text(0.5341405127638413, 0.5875, 'x[1] <= 1103.0\ngini = 0.211\nsamples = 350\nvalue = [308, 42]'),
#  Text(0.5306042104099901, 0.5625, 'x[1] <= 1083.5\ngini = 0.207\nsamples = 349\nvalue = [308, 41]'),
#  Text(0.5120869709360151, 0.5375, 'x[0] <= 9.5\ngini = 0.198\nsamples = 333\nvalue = [296, 37]'),
#  Text(0.48566139904961875, 0.5125, 'x[1] <= 965.5\ngini = 0.209\nsamples = 303\nvalue = [267, 36]'),
#  Text(0.45756437175378495, 0.4875, 'x[1] <= 957.0\ngini = 0.227\nsamples = 237\nvalue = [206, 31]'),
#  Text(0.4303237926842745, 0.4625, 'x[1] <= 599.0\ngini = 0.217\nsamples = 234\nvalue = [205, 29]'),
#  Text(0.3864515416068074, 0.4375, 'x[0] <= 2.5\ngini = 0.127\nsamples = 44\nvalue = [41, 3]'),
#  Text(0.3829152392529561, 0.4125, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.3899878439606586, 0.4125, 'x[1] <= 530.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.3864515416068074, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3935241463145099, 0.3875, 'x[2] <= 3.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.3864515416068074, 0.3625, 'x[0] <= 7.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.3829152392529561, 0.3375, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3899878439606586, 0.3375, 'x[1] <= 566.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3864515416068074, 0.3125, 'x[1] <= 555.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3829152392529561, 0.2875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3899878439606586, 0.2875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3935241463145099, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.40059675102221237, 0.3625, 'x[0] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.39706044866836115, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40413305337606364, 0.3375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4741960437617416, 0.4375, 'x[1] <= 600.5\ngini = 0.236\nsamples = 190\nvalue = [164, 26]'),
#  Text(0.47065974140789035, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4777323461155929, 0.4125, 'x[1] <= 904.5\ngini = 0.23\nsamples = 189\nvalue = [164, 25]'),
#  Text(0.4629240800088408, 0.3875, 'x[1] <= 868.5\ngini = 0.25\nsamples = 157\nvalue = [134, 23]'),
#  Text(0.44391645485689024, 0.3625, 'x[1] <= 781.5\ngini = 0.206\nsamples = 137\nvalue = [121, 16]'),
#  Text(0.41651011161454304, 0.3375, 'x[1] <= 778.0\ngini = 0.27\nsamples = 87\nvalue = [73, 14]'),
#  Text(0.41297380926069177, 0.3125, 'x[2] <= 2.5\ngini = 0.257\nsamples = 86\nvalue = [73, 13]'),
#  Text(0.39706044866836115, 0.2875, 'x[0] <= 7.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.3935241463145099, 0.2625, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.40059675102221237, 0.2625, 'x[1] <= 720.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.39706044866836115, 0.2375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.40413305337606364, 0.2375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42888716985302244, 0.2875, 'x[1] <= 670.5\ngini = 0.298\nsamples = 66\nvalue = [54, 12]'),
#  Text(0.4147419604376174, 0.2625, 'x[1] <= 666.0\ngini = 0.393\nsamples = 26\nvalue = [19, 7]'),
#  Text(0.41120565808376613, 0.2375, 'x[0] <= 3.5\ngini = 0.33\nsamples = 24\nvalue = [19, 5]'),
#  Text(0.40413305337606364, 0.2125, 'x[2] <= 3.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.40059675102221237, 0.1875, 'x[1] <= 604.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.39706044866836115, 0.1625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.40413305337606364, 0.1625, 'x[1] <= 613.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.40059675102221237, 0.1375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4076693557299149, 0.1375, 'x[3] <= 3.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.40413305337606364, 0.1125, 'x[1] <= 622.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.40059675102221237, 0.0875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4076693557299149, 0.0875, 'x[1] <= 630.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.40413305337606364, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41120565808376613, 0.0625, 'x[3] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4076693557299149, 0.0375, 'x[1] <= 658.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.40413305337606364, 0.0125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41120565808376613, 0.0125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4147419604376174, 0.0375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41120565808376613, 0.1125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4076693557299149, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4182782627914687, 0.2125, 'x[1] <= 656.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.4147419604376174, 0.1875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4218145651453199, 0.1875, 'x[1] <= 659.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4182782627914687, 0.1625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42535086749917117, 0.1625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4182782627914687, 0.2375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4430323792684274, 0.2625, 'x[1] <= 692.0\ngini = 0.219\nsamples = 40\nvalue = [35, 5]'),
#  Text(0.4394960769145762, 0.2375, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.4465686816222787, 0.2375, 'x[1] <= 711.5\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.4394960769145762, 0.2125, 'x[1] <= 702.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0
5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5597303569455189, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5668029616532213, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5668029616532213, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5376768151176926, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5889048513647916, 0.5875, 'x[1] <= 1147.5\ngini = 0.14\nsamples = 132\nvalue = [122, 10]'),
#  Text(0.5853685490109405, 0.5625, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.5924411537186429, 0.5625, 'x[1] <= 1151.5\ngini = 0.171\nsamples = 106\nvalue = [96, 10]'),
#  Text(0.5889048513647916, 0.5375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5959774560724942, 0.5375, 'x[1] <= 1164.5\ngini = 0.157\nsamples = 105\nvalue = [96, 9]'),
#  Text(0.5844844734224777, 0.5125, 'x[1] <= 1160.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5809481710686264, 0.4875, 'x[2] <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5774118687147751, 0.4625, 'x[0] <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5738755663609238, 0.4375, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5809481710686264, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5844844734224777, 0.4625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5880207757763288, 0.4875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6074704387225107, 0.5125, 'x[1] <= 1253.5\ngini = 0.134\nsamples = 97\nvalue = [90, 7]'),
#  Text(0.5950933804840314, 0.4875, 'x[2] <= 3.5\ngini = 0.068\nsamples = 57\nvalue = [55, 2]'),
#  Text(0.5915570781301801, 0.4625, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]'),
#  Text(0.5986296828378826, 0.4625, 'x[0] <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5950933804840314, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6021659851917339, 0.4375, 'x[1] <= 1195.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5986296828378826, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6057022875455852, 0.4125, 'x[0] <= 6.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6021659851917339, 0.3875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6092385898994364, 0.3875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6198474969609902, 0.4875, 'x[1] <= 1260.0\ngini = 0.219\nsamples = 40\nvalue = [35, 5]'),
#  Text(0.6127748922532876, 0.4625, 'x[0] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6092385898994364, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6163111946071389, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6269201016686927, 0.4625, 'x[1] <= 1285.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.6233837993148414, 0.4375, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.6304564040225439, 0.4375, 'x[1] <= 1289.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.6269201016686927, 0.4125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6339927063763952, 0.4125, 'x[3] <= 2.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.6304564040225439, 0.3875, 'x[1] <= 1305.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6269201016686927, 0.3625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6339927063763952, 0.3625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6375290087302464, 0.3875, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.5995137584263455, 0.6125, 'x[0] <= 3.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5959774560724942, 0.5875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6030500607801967, 0.5875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5875908249530335, 0.6375, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.6136589678417504, 0.6625, 'x[3] <= 3.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.6101226654878992, 0.6375, 'x[2] <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.606586363134048, 0.6125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6136589678417504, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6171952701956017, 0.6375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6242678749033043, 0.6875, 'x[1] <= 1432.5\ngini = 0.056\nsamples = 35\nvalue = [34, 1]'),
#  Text(0.620731572549453, 0.6625, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.6278041772571555, 0.6625, 'x[1] <= 1436.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6242678749033043, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6313404796110067, 0.6375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6186349147695878, 0.7125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6313404796110067, 0.7375, 'x[0] <= 10.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.6278041772571555, 0.7125, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.634876781964858, 0.7125, 'x[1] <= 1470.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6313404796110067, 0.6875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6384130843187092, 0.6875, 'x[1] <= 1482.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.634876781964858, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6419493866725605, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.624463532745331, 0.8125, 'x[2] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6209272303914797, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6279998350991822, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8260270471875345, 0.9375, 'x[1] <= 460.0\ngini = 0.325\nsamples = 391\nvalue = [311, 80]'),
#  Text(0.7038346778649575, 0.9125, 'x[3] <= 2.5\ngini = 0.416\nsamples = 105\nvalue = [74, 31]'),
#  Text(0.6720079566802961, 0.8875, 'x[0] <= 12.5\ngini = 0.488\nsamples = 45\nvalue = [26, 19]'),
#  Text(0.668471654326445, 0.8625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6755442590341474, 0.8625, 'x[0] <= 22.5\ngini = 0.478\nsamples = 43\nvalue = [26, 17]'),
#  Text(0.663167200795668, 0.8375, 'x[1] <= 439.0\ngini = 0.413\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.6596308984418168, 0.8125, 'x[3] <= 1.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.6525582937341142, 0.7875, 'x[0] <= 18.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.6490219913802631, 0.7625, 'x[1] <= 341.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.6454856890264118, 0.7375, 'x[0] <= 15.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6419493866725605, 0.7125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6490219913802631, 0.7125, 'x[1] <= 270.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6454856890264118, 0.6875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6525582937341142, 0.6875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6525582937341142, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6560945960879655, 0.7625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6667035031495193, 0.7875, 'x[0] <= 20.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.663167200795668, 0.7625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6702398055033706, 0.7625, 'x[2] <= 3.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6667035031495193, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6737761078572218, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6667035031495193, 0.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6879213172726268, 0.8375, 'x[1] <= 256.5\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.6808487125649243, 0.8125, 'x[2] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.677312410211073, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...
#  Text(0.7162117361034368, 0.7375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7232843408111393, 0.7375, 'x[3] <= 3.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.7197480384572881, 0.7125, 'x[1] <= 298.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7162117361034368, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7232843408111393, 0.6875, 'x[0] <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7197480384572881, 0.6625, 'x[1] <= 378.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7162117361034368, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7232843408111393, 0.6375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7268206431649906, 0.6625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7268206431649906, 0.7125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7232843408111393, 0.7875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7268206431649906, 0.8125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7303569455188419, 0.8375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7445021549342469, 0.8625, 'x[1] <= 139.0\ngini = 0.231\nsamples = 45\nvalue = [39, 6]'),
#  Text(0.7374295502265443, 0.8375, 'x[3] <= 3.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.7338932478726932, 0.8125, 'x[1] <= 123.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7303569455188419, 0.7875, 'x[1] <= 107.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7268206431649906, 0.7625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7338932478726932, 0.7625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7374295502265443, 0.7875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7409658525803956, 0.8125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7515747596419494, 0.8375, 'x[1] <= 236.0\ngini = 0.145\nsamples = 38\nvalue = [35, 3]'),
#  Text(0.7480384572880981, 0.8125, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.7551110619958007, 0.8125, 'x[1] <= 249.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.7515747596419494, 0.7875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7586473643496519, 0.7875, 'x[0] <= 14.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.7515747596419494, 0.7625, 'x[0] <= 13.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7480384572880981, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7551110619958007, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7657199690573544, 0.7625, 'x[0] <= 26.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.7621836667035031, 0.7375, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.7692562714112057, 0.7375, 'x[1] <= 294.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7657199690573544, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.772792573765057, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9482194165101117, 0.9125, 'x[1] <= 1448.5\ngini = 0.284\nsamples = 286\nvalue = [237, 49]'),
#  Text(0.9158884959664051, 0.8875, 'x[0] <= 24.5\ngini = 0.268\nsamples = 270\nvalue = [227, 43]'),
#  Text(0.880401149298265, 0.8625, 'x[0] <= 23.5\ngini = 0.301\nsamples = 195\nvalue = [159, 36]'),
#  Text(0.8562824621505138, 0.8375, 'x[1] <= 1325.0\ngini = 0.279\nsamples = 179\nvalue = [149, 30]'),
#  Text(0.8327992043319704, 0.8125, 'x[1] <= 1080.5\ngini = 0.254\nsamples = 154\nvalue = [131, 23]'),
#  Text(0.8105868051718422, 0.7875, 'x[1] <= 861.0\ngini = 0.325\nsamples = 103\nvalue = [82, 21]'),
#  Text(0.7944524256823958, 0.7625, 'x[1] <= 663.5\ngini = 0.253\nsamples = 74\nvalue = [63, 11]'),
#  Text(0.7834014808266107, 0.7375, 'x[1] <= 657.0\ngini = 0.368\nsamples = 37\nvalue = [28, 9]'),
#  Text(0.7798651784727594, 0.7125, 'x[0] <= 21.5\ngini = 0.32\nsamples = 35\nvalue = [28, 7]'),
#  Text(0.7683721958227429, 0.6875, 'x[0] <= 19.0\ngini = 0.231\nsamples = 30\nvalue = [26, 4]'),
#  Text(0.7559951375842634, 0.6625, 'x[1] <= 605.0\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.748922532876561, 0.6375, 'x[2] <= 2.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.7453862305227097, 0.6125, 'x[0] <= 13.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.7418499281688584, 0.5875, 'x[1] <= 476.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7383136258150071, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7453862305227097, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.748922532876561, 0.5875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7524588352304122, 0.6125, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.763067742291966, 0.6375, 'x[1] <= 621.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7595314399381147, 0.6125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7666040446458172, 0.6125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7807492540612222, 0.6625, 'x[3] <= 3.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0
, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.9549121449883965, 0.8375, 'x[1] <= 668.0\ngini = 0.209\nsamples = 59\nvalue = [52, 7]'),
#  Text(0.9513758426345452, 0.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9584484473422478, 0.8125, 'x[1] <= 838.0\ngini = 0.185\nsamples = 58\nvalue = [52, 6]'),
#  Text(0.9363465576306774, 0.7875, 'x[1] <= 752.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.9292739529229749, 0.7625, 'x[1] <= 711.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.9257376505691236, 0.7375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9328102552768262, 0.7375, 'x[1] <= 720.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.9292739529229749, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9363465576306774, 0.7125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.94341916233838, 0.7625, 'x[1] <= 764.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9398828599845287, 0.7375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9469554646922311, 0.7375, 'x[1] <= 801.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.94341916233838, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9504917670460824, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9805503370538181, 0.7875, 'x[0] <= 25.5\ngini = 0.124\nsamples = 45\nvalue = [42, 3]'),
#  Text(0.9681732788153387, 0.7625, 'x[1] <= 1356.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.9611006741076362, 0.7375, 'x[3] <= 2.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.957564371753785, 0.7125, 'x[1] <= 933.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9540280693999337, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9611006741076362, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9646369764614875, 0.7125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9752458835230412, 0.7375, 'x[1] <= 1396.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9717095811691899, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9787821858768925, 0.7125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9929273952922975, 0.7625, 'x[3] <= 1.5\ngini = 0.054\nsamples = 36\nvalue = [35, 1]'),
#  Text(0.9893910929384462, 0.7375, 'x[0] <= 28.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.985854790584595, 0.7125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9929273952922975, 0.7125, 'x[1] <= 1254.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9893910929384462, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9964636976461487, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9964636976461487, 0.7375, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.9805503370538181, 0.8875, 'x[0] <= 14.0\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.9770140346999668, 0.8625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9840866394076694, 0.8625, 'x[1] <= 1449.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.9805503370538181, 0.8375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9876229417615207, 0.8375, 'x[0] <= 23.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.9840866394076694, 0.8125, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9911592441153718, 0.8125, 'x[1] <= 1482.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9876229417615207, 0.7875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9946955464692231, 0.7875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
DistanceFromHome=int(input("enter DistanceFromHome"))
DailyRate=int(input("enter DailyRate"))
WorkLifeBalance=int(input("enter WorkLifeBalance"))
JobSatisfaction=int(input("enter JobSatisfaction	"))
features_col=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction']
features=mydf3[features_col]
target=mydf3.Attrition
RF2=RandomForestClassifier()
model=RF2.fit(features,target)
n_estimators=10
a=model.predict([[DistanceFromHome,DailyRate,WorkLifeBalance,JobSatisfaction]])
if a=="Yes":
  print("leave the company")
else:
  print("not leave the company")
# Out:
# enter DistanceFromHome6
# enter DailyRate613
# enter WorkLifeBalance3
# enter JobSatisfaction	1
# not leave the company
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir ="tree_visualizations_on_HR_employee_attrition"
os.makedirs(output_dir,exist_ok=True)

# %%
for i, tree in enumerate(model.estimators_):
  tree_dot_file=os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file=os.path.join(output_dir,f"tree_{i}.png")

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['DistanceFromHome','DailyRate','WorkLifeBalance','JobSatisfaction'],
                    class_names=[str(cls) for cls in model.classes_], filled=True, rounded=True)

# %%
command=f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 99 visualization saved to tree_visualizations_on_HR_employee_attrition/tree_99.png

# %%
#linear regression
import numpy as np
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
DailyRate=np.array(mydf3['DailyRate']).reshape(-1,1)
DistanceFromHome=np.array(mydf3['DistanceFromHome'])
LR.fit(DailyRate,DistanceFromHome)
LR.predict([[8.6]])
# Out:
# array([9.27203257])
