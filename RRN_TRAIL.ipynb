# %%
import numpy as np

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
#Generating some example sequential data
import pandas as pd
df=pd.read_csv("/content/earth.txt",sep='.')
#sentences=['I love anime','I hate college!','I love python','Recurrent Nueral Networks are powerful','sanjuu']
df
# Out:
# Empty DataFrame
# Columns: [Earth has a dynamic atmosphere, which sustains Earth's surface conditions and protects it from most meteoroids and UV-light at entry,  It has a composition of primarily nitrogen and oxygen,  Water vapor is widely present in the atmosphere, forming clouds that cover most of the planet,  The water vapor acts as a greenhouse gas and, together with other greenhouse gases in the atmosphere, particularly carbon dioxide (CO2), creates the conditions for both liquid surface water and water vapor to persist via the capturing of energy from the Sun's light,  ]
# Index: []

# %%
#tokenizing the words
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df)
total_words=len(tokenizer.word_index)+1
print(total_words)
# Out:
# 60

# %%
# Creating input sequences and their corresponding next words
input_sequences = []
for df in df:
    tokenized_df = tokenizer.texts_to_sequences([df])[0]
    for i in range(1, len(tokenized_df)):
        n_gram_sequence = tokenized_df[:i+1]
        input_sequences.append(n_gram_sequence)
input_sequences
# Out:
# [[17, 8],
#  [17, 8, 4],
#  [17, 8, 4, 18],
#  [17, 8, 4, 18, 5],
#  [17, 8, 4, 18, 5, 19],
#  [17, 8, 4, 18, 5, 19, 20],
#  [17, 8, 4, 18, 5, 19, 20, 21],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14],
#  [17, 8, 4, 18, 5, 19, 20, 21, 9, 10, 2, 22, 11, 12, 13, 23, 2, 24, 14, 25],
#  [17,
#   8,
#   4,
#   18,
#   5,
#   19,
#   20,
#   21,
#   9,
#   10,
#   2,
#   22,
#   11,
#   12,
#   13,
#   23,
#   2,
#   24,
#   14,
#   25,
#   26],
#  [11, 8],
#  [11, 8, 4],
#  [11, 8, 4, 27],
#  [11, 8, 4, 27, 6],
#  [11, 8, 4, 27, 6, 28],
#  [11, 8, 4, 27, 6, 28, 29],
#  [11, 8, 4, 27, 6, 28, 29, 2],
#  [11, 8, 4, 27, 6, 28, 29, 2, 30],
#  [3, 7],
#  [3, 7, 31],
#  [3, 7, 31, 32],
#  [3, 7, 31, 32, 33],
#  [3, 7, 31, 32, 33, 15],
#  [3, 7, 31, 32, 33, 15, 1],
#  [3, 7, 31, 32, 33, 15, 1, 5],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36, 37],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36, 37, 13],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36, 37, 13, 6],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36, 37, 13, 6, 1],
#  [3, 7, 31, 32, 33, 15, 1, 5, 34, 35, 36, 37, 13, 6, 1, 38],
#  [1, 3],
#  [1, 3, 7],
#  [1, 3, 7, 39],
#  [1, 3, 7, 39, 40],
#  [1, 3, 7, 39, 40, 4],
#  [1, 3, 7, 39, 40, 4, 16],
#  [1, 3, 7, 39, 40, 4, 16, 41],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1, 5],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1, 5, 46],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1, 5, 46, 47],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1, 5, 46, 47, 48],
#  [1, 3, 7, 39, 40, 4, 16, 41, 2, 42, 43, 44, 16, 45, 15, 1, 5, 46, 47, 48, 49],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59],
#  [1,
#   3,
#   7,
#   39,
#   40,
#   4,
#   16,
#   41,
#   2,
#   42,
#   43,
#   44,
#   16,
#   45,
#   15,
#   1,
#   5,
#   46,
#   47,
#   48,
#   49,
#   50,
#   1,
#   10,
#   51,
#   52,
#   53,
#   9,
#   3,
#   2,
#   3,
#   7,
#   54,
#   55,
#   56,
#   1,
#   57,
#   6,
#   58,
#   12,
#   1,
#   59,
#   14]]

# %%
# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0, 17,  8],
#        [ 0,  0,  0, ..., 17,  8,  4],
#        [ 0,  0,  0, ...,  8,  4, 18],
#        ...,
#        [ 0,  0,  1, ..., 58, 12,  1],
#        [ 0,  1,  3, ..., 12,  1, 59],
#        [ 1,  3,  7, ...,  1, 59, 14]], dtype=int32)

# %%
# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# %%
#compiling the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#training the model
model.fit(X,y,epochs=70,verbose=2)
# Out:
# Epoch 1/70
# 3/3 - 8s - loss: 4.1598 - accuracy: 0.0118 - 8s/epoch - 3s/step
# Epoch 2/70
# 3/3 - 0s - loss: 3.9568 - accuracy: 0.0588 - 158ms/epoch - 53ms/step
# Epoch 3/70
# 3/3 - 0s - loss: 3.7516 - accuracy: 0.1529 - 158ms/epoch - 53ms/step
# Epoch 4/70
# 3/3 - 0s - loss: 3.5882 - accuracy: 0.2588 - 159ms/epoch - 53ms/step
# Epoch 5/70
# 3/3 - 0s - loss: 3.4451 - accuracy: 0.3294 - 178ms/epoch - 59ms/step
# Epoch 6/70
# 3/3 - 0s - loss: 3.3172 - accuracy: 0.3647 - 261ms/epoch - 87ms/step
# Epoch 7/70
# 3/3 - 0s - loss: 3.1832 - accuracy: 0.4000 - 89ms/epoch - 30ms/step
# Epoch 8/70
# 3/3 - 0s - loss: 3.0514 - accuracy: 0.4588 - 86ms/epoch - 29ms/step
# Epoch 9/70
# 3/3 - 0s - loss: 2.9213 - accuracy: 0.4824 - 251ms/epoch - 84ms/step
# Epoch 10/70
# 3/3 - 0s - loss: 2.7739 - accuracy: 0.5412 - 237ms/epoch - 79ms/step
# Epoch 11/70
# 3/3 - 0s - loss: 2.6487 - accuracy: 0.5529 - 214ms/epoch - 71ms/step
# Epoch 12/70
# 3/3 - 0s - loss: 2.5165 - accuracy: 0.5765 - 259ms/epoch - 86ms/step
# Epoch 13/70
# 3/3 - 0s - loss: 2.3816 - accuracy: 0.6471 - 178ms/epoch - 59ms/step
# Epoch 14/70
# 3/3 - 0s - loss: 2.2466 - accuracy: 0.6471 - 207ms/epoch - 69ms/step
# Epoch 15/70
# 3/3 - 0s - loss: 2.1218 - accuracy: 0.6706 - 168ms/epoch - 56ms/step
# Epoch 16/70
# 3/3 - 0s - loss: 2.0047 - accuracy: 0.6588 - 182ms/epoch - 61ms/step
# Epoch 17/70
# 3/3 - 0s - loss: 1.8790 - accuracy: 0.6824 - 217ms/epoch - 72ms/step
# Epoch 18/70
# 3/3 - 0s - loss: 1.7806 - accuracy: 0.7529 - 130ms/epoch - 43ms/step
# Epoch 19/70
# 3/3 - 0s - loss: 1.6726 - accuracy: 0.7647 - 90ms/epoch - 30ms/step
# Epoch 20/70
# 3/3 - 0s - loss: 1.5806 - accuracy: 0.7647 - 89ms/epoch - 30ms/step
# Epoch 21/70
# 3/3 - 0s - loss: 1.4890 - accuracy: 0.8000 - 88ms/epoch - 29ms/step
# Epoch 22/70
# 3/3 - 0s - loss: 1.3924 - accuracy: 0.8118 - 82ms/epoch - 27ms/step
# Epoch 23/70
# 3/3 - 0s - loss: 1.3013 - accuracy: 0.8118 - 93ms/epoch - 31ms/step
# Epoch 24/70
# 3/3 - 0s - loss: 1.2229 - accuracy: 0.8000 - 84ms/epoch - 28ms/step
# Epoch 25/70
# 3/3 - 0s - loss: 1.1419 - accuracy: 0.8353 - 87ms/epoch - 29ms/step
# Epoch 26/70
# 3/3 - 0s - loss: 1.0736 - accuracy: 0.8353 - 101ms/epoch - 34ms/step
# Epoch 27/70
# 3/3 - 0s - loss: 1.0149 - accuracy: 0.8588 - 83ms/epoch - 28ms/step
# Epoch 28/70
# 3/3 - 0s - loss: 0.9495 - accuracy: 0.8706 - 83ms/epoch - 28ms/step
# Epoch 29/70
# 3/3 - 0s - loss: 0.8975 - accuracy: 0.8588 - 89ms/epoch - 30ms/step
# Epoch 30/70
# 3/3 - 0s - loss: 0.8486 - accuracy: 0.8706 - 81ms/epoch - 27ms/step
# Epoch 31/70
# 3/3 - 0s - loss: 0.7944 - accuracy: 0.8588 - 81ms/epoch - 27ms/step
# Epoch 32/70
# 3/3 - 0s - loss: 0.7561 - accuracy: 0.8706 - 87ms/epoch - 29ms/step
# Epoch 33/70
# 3/3 - 0s - loss: 0.7174 - accuracy: 0.8824 - 90ms/epoch - 30ms/step
# Epoch 34/70
# 3/3 - 0s - loss: 0.6763 - accuracy: 0.9059 - 84ms/epoch - 28ms/step
# Epoch 35/70
# 3/3 - 0s - loss: 0.6428 - accuracy: 0.9059 - 87ms/epoch - 29ms/step
# Epoch 36/70
# 3/3 - 0s - loss: 0.6054 - accuracy: 0.8941 - 86ms/epoch - 29ms/step
# Epoch 37/70
# 3/3 - 0s - loss: 0.5794 - accuracy: 0.9412 - 106ms/epoch - 35ms/step
# Epoch 38/70
# 3/3 - 0s - loss: 0.5517 - accuracy: 0.9176 - 84ms/epoch - 28ms/step
# Epoch 39/70
# 3/3 - 0s - loss: 0.5211 - accuracy: 0.9294 - 83ms/epoch - 28ms/step
# Epoch 40/70
# 3/3 - 0s - loss: 0.4947 - accuracy: 0.9529 - 84ms/epoch - 28ms/step
# Epoch 41/70
# 3/3 - 0s - loss: 0.4741 - accuracy: 0.9294 - 86ms/epoch - 29ms/step
# Epoch 42/70
# 3/3 - 0s - loss: 0.4512 - accuracy: 0.9412 - 83ms/epoch - 28ms/step
# Epoch 43/70
# 3/3 - 0s - loss: 0.4288 - accuracy: 0.9412 - 84ms/epoch - 28ms/step
# Epoch 44/70
# 3/3 - 0s - loss: 0.4147 - accuracy: 0.9412 - 81ms/epoch - 27ms/step
# Epoch 45/70
# 3/3 - 0s - loss: 0.3935 - accuracy: 0.9529 - 85ms/epoch - 28ms/step
# Epoch 46/70
# 3/3 - 0s - loss: 0.3732 - accuracy: 0.9647 - 84ms/epoch - 28ms/step
# Epoch 47/70
# 3/3 - 0s - loss: 0.3639 - accuracy: 0.9529 - 86ms/epoch - 29ms/step
# Epoch 48/70
# 3/3 - 0s - loss: 0.3496 - accuracy: 0.9412 - 87ms/epoch - 29ms/step
# Epoch 49/70
# 3/3 - 0s - loss: 0.3300 - accuracy: 0.9412 - 102ms/epoch - 34ms/step
# Epoch 50/70
# 3/3 - 0s - loss: 0.3158 - accuracy: 0.9529 - 87ms/epoch - 29ms/step
# Epoch 51/70
# 3/3 - 0s - loss: 0.2962 - accuracy: 0.9882 - 89ms/epoch - 30ms/step
# Epoch 52/70
# 3/3 - 0s - loss: 0.2855 - accuracy: 0.9882 - 126ms/epoch - 42ms/step
# Epoch 53/70
# 3/3 - 0s - loss: 0.2720 - accuracy: 0.9882 - 142ms/epoch - 47ms/step
# Epoch 54/70
# 3/3 - 0s - loss: 0.2604 - accuracy: 0.9882 - 214ms/epoch - 71ms/step
# Epoch 55/70
# 3/3 - 0s - loss: 0.2496 - accuracy: 0.9882 - 372ms/epoch - 124ms/step
# Epoch 56/70
# 3/3 - 0s - loss: 0.2386 - accuracy: 0.9882 - 247ms/epoch - 82ms/step
# Epoch 57/70
# 3/3 - 0s - loss: 0.2329 - accuracy: 0.9882 - 283ms/epoch - 94ms/step
# Epoch 58/70
# 3/3 - 0s - loss: 0.2169 - accuracy: 0.9882 - 334ms/epoch - 111ms/step
# Epoch 59/70
# 3/3 - 0s - loss: 0.2158 - accuracy: 0.9765 - 360ms/epoch - 120ms/step
# Epoch 60/70
# 3/3 - 0s - loss: 0.2070 - accuracy: 0.9765 - 348ms/epoch - 116ms/step
# Epoch 61/70
# 3/3 - 0s - loss: 0.2030 - accuracy: 0.9882 - 267ms/epoch - 89ms/step
# Epoch 62/70
# 3/3 - 0s - loss: 0.1926 - accuracy: 0.9882 - 262ms/epoch - 87ms/step
# Epoch 63/70
# 3/3 - 0s - loss: 0.1797 - accuracy: 0.9882 - 248ms/epoch - 83ms/step
# Epoch 64/70
# 3/3 - 0s - loss: 0.1715 - accuracy: 0.9882 - 165ms/epoch - 55ms/step
# Epoch 65/70
# 3/3 - 0s - loss: 0.1695 - accuracy: 0.9882 - 208ms/epoch - 69ms/step
# Epoch 66/70
# 3/3 - 0s - loss: 0.1625 - accuracy: 0.9882 - 209ms/epoch - 70ms/step
# Epoch 67/70
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9882 - 167ms/epoch - 56ms/step
# Epoch 68/70
# 3/3 - 0s - loss: 0.1473 - accuracy: 0.9882 - 83ms/epoch - 28ms/step
# Epoch 69/70
# 3/3 - 0s - loss: 0.1411 - accuracy: 0.9882 - 93ms/epoch - 31ms/step
# Epoch 70/70
# 3/3 - 0s - loss: 0.1369 - accuracy: 1.0000 - 84ms/epoch - 28ms/step

# %%
#Test:
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: sandal
# Enter how many words to predict: 3
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# sandal has has a
